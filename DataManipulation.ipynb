# %%
import pandas as pd

df = pd.read_csv('Details.csv')
df.drop(columns=['PaymentMode'], inplace=True)

print(df.head())
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category
# 0  B-25681    1096     658         7  Electronics  Electronic Games
# 1  B-26055    5729      64        14    Furniture            Chairs
# 2  B-25955    2927     146         8    Furniture         Bookcases
# 3  B-26093    2847     712         8  Electronics          Printers
# 4  B-25602    2617    1151         4  Electronics            Phones

# %%
df.describe()
# Out:
#             Amount      Profit     Quantity
# count  1500.000000  1500.00000  1500.000000
# mean    291.847333    24.64200     3.743333
# std     461.924620   168.55881     2.184942
# min       4.000000 -1981.00000     1.000000
# 25%      47.750000   -12.00000     2.000000
# 50%     122.000000     8.00000     3.000000
# 75%     326.250000    38.00000     5.000000
# max    5729.000000  1864.00000    14.000000

# %%
# Handling missing values
df
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category
# 0     B-25681    1096     658         7  Electronics  Electronic Games
# 1     B-26055    5729      64        14    Furniture            Chairs
# 2     B-25955    2927     146         8    Furniture         Bookcases
# 3     B-26093    2847     712         8  Electronics          Printers
# 4     B-25602    2617    1151         4  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-25700       7      -3         2     Clothing       Hankerchief
# 1496  B-25757    3151     -35         7     Clothing          Trousers
# 1497  B-25973    4141    1698        13  Electronics          Printers
# 1498  B-25698       7      -2         1     Clothing       Hankerchief
# 1499  B-25993    4363     305         5    Furniture            Tables
#
# [1500 rows x 6 columns]

# %%
#Filling missing values
#Updating column values
df = df.rename(columns={'Amount': 'Amount No'})

df['New Amount'] = df['Amount No'] 
df['New Amount'] = df['New Amount'].fillna(df['New Amount'].mean())
df['New Amount'] = df['New Amount'].astype(float)
df
# Out:
#      Order ID  Amount No  Profit  Quantity     Category      Sub-Category  \
# 0     B-25681       1096     658         7  Electronics  Electronic Games
# 1     B-26055       5729      64        14    Furniture            Chairs
# 2     B-25955       2927     146         8    Furniture         Bookcases
# 3     B-26093       2847     712         8  Electronics          Printers
# 4     B-25602       2617    1151         4  Electronics            Phones
# ...       ...        ...     ...       ...          ...               ...
# 1495  B-25700          7      -3         2     Clothing       Hankerchief
# 1496  B-25757       3151     -35         7     Clothing          Trousers
# 1497  B-25973       4141    1698        13  Electronics          Printers
# 1498  B-25698          7      -2         1     Clothing       Hankerchief
# 1499  B-25993       4363     305         5    Furniture            Tables
#
#       New Amount
# 0         1096.0
# 1         5729.0
# 2         2927.0
# ...

# %%
# Applying a function to a column
df['Quantity'] = df['Quantity'].apply(lambda x : x * 2)
df
# Out:
#      Order ID  Amount No  Profit  Quantity     Category      Sub-Category  \
# 0     B-25681       1096     658        14  Electronics  Electronic Games
# 1     B-26055       5729      64        28    Furniture            Chairs
# 2     B-25955       2927     146        16    Furniture         Bookcases
# 3     B-26093       2847     712        16  Electronics          Printers
# 4     B-25602       2617    1151         8  Electronics            Phones
# ...       ...        ...     ...       ...          ...               ...
# 1495  B-25700          7      -3         4     Clothing       Hankerchief
# 1496  B-25757       3151     -35        14     Clothing          Trousers
# 1497  B-25973       4141    1698        26  Electronics          Printers
# 1498  B-25698          7      -2         2     Clothing       Hankerchief
# 1499  B-25993       4363     305        10    Furniture            Tables
#
#       New Amount
# 0         1096.0
# 1         5729.0
# 2         2927.0
# ...

# %%
# Data aggregation and grouping

grouped_data = df.groupby('Category')['Profit'].mean()
print(grouped_data)
# Out:
# Category
# Clothing       14.041096
# Electronics    42.733766
# Furniture      43.111111
# Name: Profit, dtype: float64

# %%
# # Data aggregation and grouping

grouped_data = df.groupby('Category')['Profit'].mean()
print(grouped_data)

# %%
grouped_sum = df.groupby(['Category', 'Sub-Category'])['Profit'].sum()
print(grouped_sum)
# Out:
# Category     Sub-Category
# Clothing     Hankerchief         1823
#              Kurti               -401
#              Leggings            -130
#              Saree               4057
#              Shirt               1513
#              Skirt               -315
#              Stole               2431
#              T-shirt             1500
#              Trousers            2847
# Electronics  Accessories         3353
#              Electronic Games    -644
#              Phones              1847
#              Printers            8606
# Furniture    Bookcases           6516
#              Chairs              1627
#              Furnishings         -806
#              Tables              3139
# Name: Profit, dtype: int64

# %%
df.columns
# Out:
# Index(['Order ID', 'Amount No', 'Profit', 'Quantity', 'Category',
#        'Sub-Category', 'New Amount'],
#       dtype='object')

# %%
#Merging and joining data frames

df1 = pd.DataFrame({'Key': ['A', 'B', 'C', 'D'], 'Values': [1, 2, 3, 4]})
df2 = pd.DataFrame({'Key' : ['E', 'F', 'G','H'], 'Values' : [5, 6, 7, 8] }) 

df1
# Out:
#   Key  Values
# 0   A       1
# 1   B       2
# 2   C       3
# 3   D       4

# %%
import pandas as pd


url = "https://en.wikipedia.org/wiki/Help:Table"
df = pd.read_html(url)
df
# Out:
# [    0                                                  1
#  0 NaN  This Help page uses TemplateStyles: Help:Table...,
#      0                                                  1                2
#  0 NaN  This help page is a how-to guide. It explains ...  ShortcutH:TABLE,
#                                              Wikitext
#  0  Cheatsheet All wikitext Sound files Visual fil...
#  1                                                vte,
#    Header A Header B Header C
#  0  row 1 A  row 1 B  row 1 C
#  1  row 2 A  row 2 B  row 2 C
#  2  row 3 A  row 3 B  row 3 C,
#     Table element Wikitext  Required  \
#  0    Table start       {|  Required
#  1        Caption       |+  Optional
#  2  Row separator       |-  Required
#  3    Header cell  ! or !!  Optional
#  4      Data cell  | or ||  Optional
#  5      Table end       |}  Required
#
#                                           Usage notes
#  0                 Note: {| Entire table goes here |}
# ...

# %%
pip install lxml
# Out:
# ...
#   Using cached lxml-6.0.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Using cached lxml-6.0.0-cp312-cp312-win_amd64.whl (4.0 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
